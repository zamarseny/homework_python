# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Загрузить исходные данные data.csv

# %%
path=r'C:\Users\Arsen\Downloads\data-scientist4-master/data-scientist4-master\3. Python Preprocessing\Python Preprocessing - Laboratory Work/data.csv'

# %%
data=pd.read_csv(path, sep=';')

# %%
ls!
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is 5464-2836
#
#  Directory of C:\Users\Arsen\Downloads\homework_python\homework_python-master
# File Not Found

# %%
data.head(10).T
# Out:
#                      0        1        2        3        4        5        6  \
# Id                   1        2        3        4        5        6        7
# MSSubClass          60       20       60       70       60       50       20
# MSZoning            RL       RL       RL       RL       RL       RL       RL
# LotFrontage         65       80       68       60       84       85       75
# LotArea           8450     9600    11250     9550    14260    14115    10084
# Street            Pave     Pave     Pave     Pave     Pave     Pave     Pave
# Alley              NaN      NaN      NaN      NaN      NaN      NaN      NaN
# LotShape           Reg      Reg      IR1      IR1      IR1      IR1      Reg
# LandContour        Lvl      Lvl      Lvl      Lvl      Lvl      Lvl      Lvl
# Utilities       AllPub   AllPub   AllPub   AllPub   AllPub   AllPub   AllPub
# LotConfig       Inside      FR2   Inside   Corner      FR2   Inside   Inside
# ...

# %% [markdown]
# # Провести первоначальный анализ предложенных данных

# %%
#pd.options.display.max_info_columns
#max_cols

# %%
data.describe(include='all').T.head(81)
# Out:
#               count unique      top  freq      mean       std   min     25%  \
# Id             1460    NaN      NaN   NaN     730.5    421.61     1  365.75
# MSSubClass     1460    NaN      NaN   NaN   56.8973   42.3006    20      20
# MSZoning       1460      5       RL  1151       NaN       NaN   NaN     NaN
# LotFrontage    1201    NaN      NaN   NaN     70.05   24.2848    21      59
# LotArea        1460    NaN      NaN   NaN   10516.8   9981.26  1300  7553.5
# Street         1460      2     Pave  1454       NaN       NaN   NaN     NaN
# Alley            91      2     Grvl    50       NaN       NaN   NaN     NaN
# LotShape       1460      4      Reg   925       NaN       NaN   NaN     NaN
# LandContour    1460      4      Lvl  1311       NaN       NaN   NaN     NaN
# Utilities      1460      2   AllPub  1459       NaN       NaN   NaN     NaN
# LotConfig      1460      5   Inside  1052       NaN       NaN   NaN     NaN
# ...

# %% [markdown]
# # Предложить стратегию по работе с пропущенными значениями в данных

# %%
data.info(max_cols=81)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
# Id               1460 non-null int64
# MSSubClass       1460 non-null int64
# MSZoning         1460 non-null object
# LotFrontage      1201 non-null float64
# LotArea          1460 non-null int64
# Street           1460 non-null object
# Alley            91 non-null object
# LotShape         1460 non-null object
# LandContour      1460 non-null object
# Utilities        1460 non-null object
# LotConfig        1460 non-null object
# LandSlope        1460 non-null object
# Neighborhood     1460 non-null object
# Condition1       1460 non-null object
# Condition2       1460 non-null object
# BldgType         1460 non-null object
# HouseStyle       1460 non-null object
# OverallQual      1460 non-null int64
# OverallCond      1460 non-null int64
# YearBuilt        1460 non-null int64
# YearRemodAdd     1460 non-null int64
# RoofStyle        1460 non-null object
# ...

# %% [markdown]
# ЧИСЛОВЫЕ:
# MasVnrArea       1452 non-null float64 Masonry veneer area in square feet ()
# GarageYrBlt      1379 non-null float64 Year garage was built (replace with YearBuilt)
# LotFrontage      1201 non-null float64 Linear feet of street connected to property
#
# Остальные пропуски - категориальные
# MasVnrType       1452 non-null object
# BsmtQual         1423 non-null object
# BsmtCond         1423 non-null object
# BsmtExposure     1422 non-null object
# BsmtFinType1     1423 non-null object
# BsmtFinType2     1422 non-null object
# Electrical       1459 non-null object
# GarageType       1379 non-null object
# GarageFinish     1379 non-null object
# GarageQual       1379 non-null object
# GarageCond       1379 non-null object
# FireplaceQu      770 non-null object
# FireplaceQu      770 non-null object
# Alley            91 non-null object
# PoolQC           7 non-null object (Pool quality   -addition to pool area)
# !Fence            281 non-null object (Fence quality забор)
# !MiscFeature      54 non-null object (Miscellaneous feature not covered in other categories: 2nd Gar, Elevator, tennis)

# %% [markdown]
# Известные мне методы работы с пропусками:
# 1) dropna
# 2) замена на среднее (площадь и длина кладки)
# 3) быть может, имеет смысл заменить на другую переменную, которая известна (для года)

# %%
#check=data['LotArea', 'YearBuilt', 'SaleCategory' ,'MasVnrArea', 'GarageYrBlt', 'LotFrontage']

# %%
#data.dropna(subset=['MasVnrArea', 'GarageYrBlt', 'LotFrontage'])

# %%
import seaborn as sns
sns.pairplot(data.dropna(subset=['MasVnrArea', 'GarageYrBlt', 'LotFrontage']), vars=['GrLivArea', 'YearBuilt' \
                        #, '1stFlrSF ' \
                         ,'MasVnrArea', \
                         'GarageYrBlt', \
                         'LotFrontage' \
                            ],
                 kind='scatter', dropna=True, 
             palette=('g', 'r'), hue='SaleCategory')
#MasVnrArea, GarageYrBlt, LotFrontage
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
#data(['GarageYrBlt'])#.corr()
#, 'YearBuilt'
corr_matrix = data.corr()
corr_matrix["GarageYrBlt"].sort_values(ascending=False)
# Out:
# GarageYrBlt      1.000000
# YearBuilt        0.825667
# YearRemodAdd     0.642277
# GarageCars       0.588920
# GarageArea       0.564567
# OverallQual      0.547766
# FullBath         0.484557
# SaleCategory     0.419525
# TotalBsmtSF      0.322445
# MasVnrArea       0.252691
# 1stFlrSF         0.233449
# GrLivArea        0.231197
# OpenPorchSF      0.228425
# WoodDeckSF       0.224577
# HalfBath         0.196785
# BsmtUnfSF        0.190708
# BsmtFinSF1       0.153484
# TotRmsAbvGrd     0.148112
# BsmtFullBath     0.124553
# MSSubClass       0.085072
# 2ndFlrSF         0.070832
# LotFrontage      0.070250
# Fireplaces       0.046822
# 3SsnPorch        0.023544
# MoSold           0.005337
# Id               0.000072
# YrSold          -0.001014
# PoolArea        -0.014501
# LotArea         -0.024947
# MiscVal         -0.032417
# LowQualFinSF    -0.036363
# BedroomAbvGr    -0.064518
# ScreenPorch     -0.075418
# BsmtHalfBath    -0.077464
# BsmtFinSF2      -0.088011
# ...

# %%
corr_matrix["MasVnrArea"].sort_values(ascending=False)
# Out:
# MasVnrArea       1.000000
# OverallQual      0.411876
# GrLivArea        0.390857
# GarageArea       0.373066
# GarageCars       0.364204
# TotalBsmtSF      0.363936
# 1stFlrSF         0.344501
# SaleCategory     0.334187
# YearBuilt        0.315707
# TotRmsAbvGrd     0.280682
# FullBath         0.276833
# BsmtFinSF1       0.264736
# GarageYrBlt      0.252691
# Fireplaces       0.249070
# HalfBath         0.201444
# LotFrontage      0.193458
# YearRemodAdd     0.179618
# 2ndFlrSF         0.174561
# WoodDeckSF       0.159718
# OpenPorchSF      0.125703
# BsmtUnfSF        0.114442
# LotArea          0.104160
# BedroomAbvGr     0.102821
# BsmtFullBath     0.085310
# ScreenPorch      0.061466
# BsmtHalfBath     0.026673
# MSSubClass       0.022936
# 3SsnPorch        0.018796
# PoolArea         0.011723
# MoSold          -0.005965
# YrSold          -0.008201
# MiscVal         -0.029815
# KitchenAbvGr    -0.037610
# Id              -0.050298
# LowQualFinSF    -0.069071
# ...

# %%
corr_matrix["LotFrontage"].sort_values(ascending=False)
# Out:
# LotFrontage      1.000000
# 1stFlrSF         0.457181
# LotArea          0.426095
# GrLivArea        0.402797
# TotalBsmtSF      0.392075
# TotRmsAbvGrd     0.352096
# GarageArea       0.344997
# SaleCategory     0.298255
# GarageCars       0.285691
# Fireplaces       0.266639
# BedroomAbvGr     0.263170
# OverallQual      0.251646
# BsmtFinSF1       0.233633
# PoolArea         0.206167
# FullBath         0.198769
# MasVnrArea       0.193458
# OpenPorchSF      0.151972
# BsmtUnfSF        0.132644
# YearBuilt        0.123349
# BsmtFullBath     0.100949
# YearRemodAdd     0.088866
# WoodDeckSF       0.088521
# 2ndFlrSF         0.080177
# GarageYrBlt      0.070250
# 3SsnPorch        0.070029
# HalfBath         0.053532
# BsmtFinSF2       0.049900
# ScreenPorch      0.041383
# LowQualFinSF     0.038469
# MoSold           0.011200
# EnclosedPorch    0.010700
# YrSold           0.007450
# MiscVal          0.003368
# KitchenAbvGr    -0.006069
# BsmtHalfBath    -0.007234
# ...

# %%
data['MasVnrArea'].mean()
# Out:
# 103.68526170798899

# %%
#год заменям на год
data['GarageYrBlt'].fillna(data['YearBuilt'], inplace=True)

#остальное - на среднее
data['MasVnrArea'].fillna(103.685, inplace=True) 
data['LotFrontage'].fillna(70.049958, inplace=True)

# %% [markdown]
# # Предложить стратегию по работе с категориальными переменными

# %% [markdown]
# пробую WoE, т.к. датасет небольшой (1400 записей), а фичей много (100)

# %%
y = data['SaleCategory'].copy()

# %%
from sklearn.cross_validation import train_test_split
data_train, data_test, y_train, y_test = train_test_split(data, y, test_size=0.2, random_state=42)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
def get_counts(df_train, df_test, col, target_col):
    category_val_dict = (
        df_train[df_train[target_col] == 1][col].value_counts()
        /
        df_train[col].value_counts()
    ).to_dict()
    df_train[col + '_counts'] = df_train[col].apply(category_val_dict.get)
    df_test[col + '_counts'] = df_test[col].apply(category_val_dict.get)
    return df_train, df_test

# %%
def get_woe_v1(df_train, df_test, col, target_col):
    all_good = len(df_train[df_train[target_col] == 1][col])
    all_bad = len(df_train[df_train[target_col] == 0][col])
    odds_series = (
        df_train[df_train[target_col] == 1][col].value_counts()
        /
        df_train[df_train[target_col] == 0][col].value_counts()
    )
    odds_series = odds_series / all_good * all_bad
    category_woe_dict = np.log(odds_series).to_dict()
    df_train[col + '_woe'] = df_train[col].apply(category_woe_dict.get)
    df_test[col + '_woe'] = df_test[col].apply(category_woe_dict.get)
    return df_train, df_test

# %%
# build counts
columns_to_get_counts = [
    'MSZoning', 'Street', 
    'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
    'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 
    'BldgType', 'HouseStyle', 'RoofStyle', 
    'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 
    'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'Heating', 
    'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual', 'Functional', 'FireplaceQu', 'GarageType', 
    'GarageFinish', 
    'GarageQual', 'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature', 'MoSold',
    'YrSold', 'SaleType', 
    'SaleCondition'
]
    
for col_get_prob in columns_to_get_counts:
    data_train, data_test = get_woe_v1(data_train, data_test, col_get_prob, 'SaleCategory')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':

# %%
data_train.shape#.T
# Out:
# (1168, 126)

# %% [markdown]
# # Провести углубленный анализ данных (корреляции переменных, визуализация взаимосвязей)

# %%
data_train.corr()
# Out:
#                              Id    MSSubClass   LotFrontage       LotArea  \
# Id                 1.000000e+00  2.216414e-03 -3.820492e-03 -3.341069e-02
# MSSubClass         2.216414e-03  1.000000e+00 -3.429487e-01 -1.165010e-01
# LotFrontage       -3.820492e-03 -3.429487e-01  1.000000e+00  2.991539e-01
# LotArea           -3.341069e-02 -1.165010e-01  2.991539e-01  1.000000e+00
# OverallQual       -1.787982e-02  2.971946e-02  2.303522e-01  1.020882e-01
# OverallCond        2.957099e-02 -5.276761e-02 -4.606537e-02  1.625109e-03
# YearBuilt         -2.214237e-02 -1.928339e-03  1.176856e-01  1.354113e-02
# YearRemodAdd      -3.256040e-02  3.608112e-02  8.470257e-02  1.721562e-02
# MasVnrArea        -2.364064e-02 -1.346902e-02  2.020995e-01  1.256076e-01
# BsmtFinSF1        -1.179002e-02 -8.094376e-02  2.185805e-01  2.242700e-01
# BsmtFinSF2        -9.281900e-03 -7.420522e-02  5.443598e-02  1.223663e-01
# BsmtUnfSF         -2.552235e-03 -1.318539e-01  1.157720e-01 -1.481508e-02
# ...

# %%
#data.iloc[:, 82:83]
#data.loc[:, [82,83]]

data_train.drop(columns=columns_to_get_counts, inplace=True)
#, inplace=True
data_test.drop(columns=columns_to_get_counts, inplace=True)

#columns_to_get_counts
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:3697: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
data_train.drop(columns=['SaleCategory'], inplace=True)
data_test.drop(columns=['SaleCategory'], inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-59-6b27acaff55e> in <module>()
# ----> 1 data_train.drop(columns=['SaleCategory'], inplace=True)
#       2 data_test.drop(columns=['SaleCategory'], inplace=True)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3695                                            index=index, columns=columns,
#    3696                                            level=level, inplace=inplace,
# -> 3697                                            errors=errors)
#    3698
#    3699     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3109         for axis, labels in axes.items():
# ...

# %%
#data_train.corr()
corr = data.corr()
fig, ax = plt.subplots(figsize=(20.0, 20.00) )
sns.heatmap(corr, 
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values)

# %%
sns.pairplot(data_train, vars=['GarageCars', 'GarageArea' ],
                 kind='scatter', dropna=True)

# %%
#площадь гаража коррелирует с количеством машин. Годы постройки дома и гаража также коррелируют

# %%
#Перед применением PCA решил отшкалировать данные

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc = StandardScaler()
sc.fit(data_train)
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
data_train_sc = sc.transform(data_train)

# %%
data_test_sc = sc.transform(data_test)

# %%
data_train_sc=pd.DataFrame(data_train_sc,columns=  data_train.columns)
data_test_sc=pd.DataFrame(data_test_sc,columns=  data_test.columns)

# %%
data_test_sc.shape
# Out:
# (292, 80)

# %% [markdown]
# # Провести сокращение размерности датасета с использованием метода PCA

# %%
data_train.dtypes
#data_train.info(max_cols=81)
# Out:
# Id                     int64
# MSSubClass             int64
# LotFrontage          float64
# LotArea                int64
# OverallQual            int64
# OverallCond            int64
# YearBuilt              int64
# YearRemodAdd           int64
# MasVnrArea           float64
# BsmtFinSF1             int64
# BsmtFinSF2             int64
# BsmtUnfSF              int64
# TotalBsmtSF            int64
# 1stFlrSF               int64
# 2ndFlrSF               int64
# LowQualFinSF           int64
# GrLivArea              int64
# BsmtFullBath           int64
# BsmtHalfBath           int64
# FullBath               int64
# HalfBath               int64
# BedroomAbvGr           int64
# KitchenAbvGr           int64
# TotRmsAbvGrd           int64
# Fireplaces             int64
# GarageYrBlt          float64
# GarageCars             int64
# GarageArea             int64
# WoodDeckSF             int64
# OpenPorchSF            int64
#                       ...
# Exterior1st_woe      float64
# ...

# %%
data_train.fillna(0, inplace=True) 
data_test.fillna(0, inplace=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:3790: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   downcast=downcast, **kwargs)

# %%
from sklearn.decomposition import PCA
pca = PCA().fit(data_train_sc)

cum_evr = np.cumsum(pca.explained_variance_ratio_)
xs = np.arange(cum_evr.size) + 1
plt.plot(xs, cum_evr, linewidth=2)
plt.grid()
plt.xlabel('n_components')
plt.ylabel('explained_variance_ratio_')
# Out:
# Text(0,0.5,'explained_variance_ratio_')

# %%
#беру 59 фичей, которые объясняют 95 процентов вариации

# %%
for i in zip(xs, cum_evr):
    print(i)
# Out:
# (1, 0.16654107986690567)
# (2, 0.21840253210275268)
# (3, 0.26833448464796295)
# (4, 0.2994919860105779)
# (5, 0.3296183429375965)
# (6, 0.3551689868721352)
# (7, 0.3795227972624957)
# (8, 0.40114872083676556)
# (9, 0.42148009936690906)
# (10, 0.4405778399349822)
# (11, 0.45864204357652905)
# (12, 0.4761717621859654)
# (13, 0.493190339788174)
# (14, 0.509893440920335)
# (15, 0.5256779141710445)
# (16, 0.5412429592203405)
# (17, 0.5564513645727814)
# (18, 0.5711725435828007)
# (19, 0.5858248545969813)
# (20, 0.6001998241920977)
# (21, 0.6143257070324563)
# (22, 0.6282340453193889)
# (23, 0.641799175538614)
# (24, 0.655064891578914)
# (25, 0.6681065782747666)
# (26, 0.6804369111068723)
# (27, 0.692412676993242)
# (28, 0.7042647471848744)
# (29, 0.7158725729020118)
# (30, 0.727264997352857)
# (31, 0.7382340754486526)
# (32, 0.7490489763202112)
# (33, 0.7595139404149029)
# (34, 0.7697210326420807)
# (35, 0.7797855737384723)
# (36, 0.7895992831139511)
# (37, 0.7991037416231144)
# ...

# %%
from sklearn.decomposition import KernelPCA

lin_pca = KernelPCA(n_components = 59, kernel="linear", fit_inverse_transform=True)

# %%
lin_pca.fit(data_train_sc)
# Out:
# KernelPCA(alpha=1.0, coef0=1, copy_X=True, degree=3, eigen_solver='auto',
#      fit_inverse_transform=True, gamma=None, kernel='linear',
#      kernel_params=None, max_iter=None, n_components=59, n_jobs=1,
#      random_state=None, remove_zero_eig=False, tol=0)

# %%
#tbc
fetures_short_list_train=lin_pca.transform(data_train_sc)
fetures_short_list_test=lin_pca.transform(data_test_sc)

# %%
print('train.shape:', len(fetures_short_list_train), 'x',len(fetures_short_list_train[0]))
print('test.shape:', len(fetures_short_list_test), 'x',len(fetures_short_list_test[0]))
# Out:
# train.shape: 1168 x 59
# test.shape: 292 x 59

# %% [markdown]
# # Сделать кросс-валидацию данных с использованием подхода K-fold (n_folds=5)

# %%
from sklearn.model_selection import cross_val_score

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr=LogisticRegression(penalty='l2')
lr.fit(data_train_sc, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
scores = cross_val_score(lr, data_train_sc, y_train, cv=5)#, scoring='accuracy'
print(scores)
print(scores.mean())
# Out:
# [0.91452991 0.90598291 0.94871795 0.91416309 0.9055794 ]
# 0.9177946517002311

# %%
print("Accuracy: %0.2f (+/- %0.2f)" % (scores.mean(), scores.std() * 2))
# Out:
# Accuracy: 0.92 (+/- 0.03)

# %%
lr.score(data_test_sc, y_test)
# Out:
# 0.934931506849315

# %% [markdown]
# # Решить задачу бинарной классификации и предсказать переменную ‘SalesCategory’ протестировав несколько алгоритмов (Logistic Regression, SVM, Random Forest, Gradient Boosting)10

# %%
from sklearn.metrics import roc_auc_score, roc_curve, f1_score, accuracy_score, precision_score, recall_score
#import xgboost

# %%
col = ['model', 'fetures', 'Accuracy', 'F1-Score', 'Precision', 'Recall'] 

#ind = ['model_pow_%d' % i for i in range(1, 16)]
ind = [i for i in range(17)]
model_comparison = pd.DataFrame(index=ind, columns=col)

# %%
lr.fit(data_train_sc, y_train)
#y_pred_tr=lr.predict(data_train_sc)
y_pred_te=lr.predict(data_test_sc)

# %%
n=0

# %%
model_comparison.iloc[n, : ]=['Logistic Regression', 'initial_data',\
                                accuracy_score(y_test, y_pred_te), \
                                  f1_score(y_test, y_pred_te),\
                               precision_score(y_test, y_pred_te), \
                              recall_score(y_test, y_pred_te)]
n+=1

# %%
lr.fit(fetures_short_list_train, y_train)
y_pred_te=lr.predict(fetures_short_list_test)

# %%
model_comparison.iloc[n, : ]=['Logistic Regression', '59_dimens_data',\
                                accuracy_score(y_test, y_pred_te), \
                                  f1_score(y_test, y_pred_te),\
                               precision_score(y_test, y_pred_te), \
                              recall_score(y_test, y_pred_te)]
n+=1

# %%
model_comparison.head()
# Out:
#                  model         fetures  Accuracy  F1-Score Precision    Recall
# 0  Logistic Regression    initial_data  0.934932  0.886228  0.870588  0.902439
# 1  Logistic Regression  38_dimens_data  0.917808  0.853659  0.853659  0.853659
# 2                  svm    initial_data  0.941781   0.89697  0.891566  0.902439
# 3                  svm  38_dimens_data  0.921233  0.862275  0.847059  0.878049
# 4           forest_clf    initial_data  0.955479  0.920245  0.925926  0.914634

# %%
from sklearn.svm import SVC

# %%
clf = SVC(kernel='linear')

# %%
clf.fit(data_train_sc, y_train)
#y_pred_tr=lr.predict(data_train_sc)
y_pred_te=clf.predict(data_test_sc)

# %%
model_comparison.iloc[n, : ]=['svm', 'initial_data',\
                                accuracy_score(y_test, y_pred_te), \
                                  f1_score(y_test, y_pred_te),\
                               precision_score(y_test, y_pred_te), \
                              recall_score(y_test, y_pred_te)]
n+=1

# %%
clf.fit(fetures_short_list_train, y_train)
y_pred_te=lr.predict(fetures_short_list_test)

# %%
n=3
model_comparison.iloc[n, : ]=['svm', '59_dimens_data',\
                                accuracy_score(y_test, y_pred_te), \
                                  f1_score(y_test, y_pred_te),\
                               precision_score(y_test, y_pred_te), \
                              recall_score(y_test, y_pred_te)]
n+=1

# %%
model_comparison.head()
# Out:
#                  model         fetures  Accuracy  F1-Score Precision    Recall
# 0  Logistic Regression    initial_data  0.934932  0.886228  0.870588  0.902439
# 1  Logistic Regression  38_dimens_data  0.917808  0.853659  0.853659  0.853659
# 2                  svm    initial_data  0.941781   0.89697  0.891566  0.902439
# 3                  svm  59_dimens_data  0.917808  0.853659  0.853659  0.853659
# 4           forest_clf    initial_data  0.955479  0.920245  0.925926  0.914634

# %%
from sklearn.ensemble import RandomForestClassifier
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d

# %%
forest = RandomForestClassifier(n_estimators=100, max_features='auto')
forest.fit(data_train_sc, y_train)
y_pred_te=forest.predict(data_test_sc)

# %%
cums=0
for i in sorted(zip(forest.feature_importances_, data_train_sc.columns), key=lambda x: -abs(x[0])):
    cums+=i[0]            
    print(i[1], i[0], cums)
# Out:
# GrLivArea 0.09882622104076144 0.09882622104076144
# OverallQual 0.07755247758737442 0.17637869862813588
# Neighborhood_woe 0.06515850716951216 0.24153720579764804
# TotalBsmtSF 0.05711750278648752 0.29865470858413556
# 1stFlrSF 0.04912921332170268 0.34778392190583823
# ExterQual_woe 0.047935566556690574 0.3957194884625288
# YearBuilt 0.046127723985868514 0.4418472124483973
# GarageArea 0.04275676126534148 0.4846039737137388
# 2ndFlrSF 0.033451496031155624 0.5180554697448945
# KitchenQual_woe 0.02963071230233432 0.5476861820472287
# LotArea 0.02867836470761346 0.5763645467548422
# GarageYrBlt 0.025381331851022017 0.6017458786058641
# FullBath 0.024157663754930437 0.6259035423607946
# BsmtQual_woe 0.022129574434917428 0.6480331167957121
# BsmtFinSF1 0.01967389420821874 0.6677070110039308
# YearRemodAdd 0.019318319850459908 0.6870253308543908
# GarageCars 0.018791240531432073 0.7058165713858229
# TotRmsAbvGrd 0.017321553095707508 0.7231381244815304
# ...

# %%
model_comparison.iloc[n, : ]=['forest_clf', 'initial_data',\
                                accuracy_score(y_test, y_pred_te), \
                                  f1_score(y_test, y_pred_te),\
                               precision_score(y_test, y_pred_te), \
                              recall_score(y_test, y_pred_te)]
n+=1

# %%
forest.fit(fetures_short_list_train, y_train)
forest=lr.predict(fetures_short_list_test)

# %%
model_comparison.iloc[n, : ]=['forest_clf', '59_dimens_data',\
                                accuracy_score(y_test, y_pred_te), \
                                  f1_score(y_test, y_pred_te),\
                               precision_score(y_test, y_pred_te), \
                              recall_score(y_test, y_pred_te)]
n+=1

# %%
model_comparison.head(6)
# Out:
#                  model         fetures  Accuracy  F1-Score Precision    Recall
# 0  Logistic Regression    initial_data  0.934932  0.886228  0.870588  0.902439
# 1  Logistic Regression  38_dimens_data  0.917808  0.853659  0.853659  0.853659
# 2                  svm    initial_data  0.941781   0.89697  0.891566  0.902439
# 3                  svm  59_dimens_data  0.917808  0.853659  0.853659  0.853659
# 4           forest_clf    initial_data  0.958904     0.925  0.948718  0.902439
# 5           forest_clf  59_dimens_data  0.958904     0.925  0.948718  0.902439

# %%
Вывод - PCA, как я его применил не дал улучшения и не сильно сократил размерность. 
Самый лучший метод без подбора параметров - Random Forest Classifier.
Удивительно высокая точность

# %%
xgb = xgboost.XGBClassifier(max_depth=5, n_jobs=-1)
xgb.fit(data_train, y_train)
y_train_predict = xgb.predict_proba(data_train)[:, 1]
y_test_predict = xgb.predict_proba(data_test)[:, 1]
roc_auc_train = np.round(roc_auc_score(y_train, y_train_predict), 2)
roc_auc_test = np.round(roc_auc_score(y_test, y_test_predict), 2)
print("Train: ", roc_auc_train)
print("Test: ", roc_auc_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-61-638ff1603c89> in <module>()
# ----> 1 xgb = xgboost.XGBClassifier(max_depth=5, n_jobs=-1)
#       2 xgb.fit(data_train, y_train)
#       3 y_train_predict = xgb.predict_proba(data_train)[:, 1]
#       4 y_test_predict = xgb.predict_proba(data_test)[:, 1]
#       5 roc_auc_train = np.round(roc_auc_score(y_train, y_train_predict), 2)
#
# NameError: name 'xgboost' is not defined

# %%
#'xgboost' сходу не установился на моем компьютере с Windows. Вылетает с ошибкой
#Ранее пользовался другим компьютером с Ubuntu. Там 'xgboost' установился

# %% [markdown]
# # Проверить качество классификации с использованием следующих метрик: Accuracy, F1-Score, Precision, Recall

# %%
#выше

# %% [markdown]
# # *Сравнить результаты классификации при использовании изначального датасета и датасета с уменьшенной размерностью

# %%
#выше

# %% [markdown]
# # Загрузить ipython notebook с результатами работы на github репозиторий
